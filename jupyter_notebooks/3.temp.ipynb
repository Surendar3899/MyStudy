# %%
# %load_ext sql

# %%
# %sql mysql+mysqlconnector://root:Test%401234@localhost/randomgenerate

# %%
# %%sql
# show databases;

# %%
# %%sql
# use randomgenerate;

# %%
# %%sql
# show tables;
# Out:
# UsageError: Cell magic `%%sql` not found.

# %%
# %%sql
# select * from customers;

# %%
# %%sql
# select * from orders;

# %%
# %%sql
# select o.id as newid,o.customer_id,o.order_date,0.amount,c.* from orders o left join customers c on o.customer_id = c.id;

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql
