# %%
# %load_ext sql

# %%
# %sql mysql+mysqlconnector://root:Test%401234@localhost/dataengineering

# %%
# %%sql
# show tables;

# %%
# %%sql
# CREATE TABLE CustomerTransactions (
#     id INT PRIMARY KEY,
#     login_device VARCHAR(50),
#     customer_name VARCHAR(100),
#     ip_address VARCHAR(20),
#     product VARCHAR(100),
#     amount DECIMAL(10, 2),
#     is_placed BOOLEAN,
#     is_viewed BOOLEAN,
#     transaction_status VARCHAR(20)
# );

# %%
# %%sql
# INSERT INTO CustomerTransactions VALUES
# (1, 'Mobile', 'Ravi', '192.168.1.1', 'Laptop', 50000.00, TRUE, FALSE, 'Completed'),
# (2, 'Desktop', 'Priya', '192.168.1.2', 'Smartphone', 20000.00, TRUE, TRUE, 'Completed'),
# (3, 'Tablet', 'Arjun', '192.168.1.3', 'Headphones', 1500.00, FALSE, TRUE, 'Failed'),
# (4, 'Mobile', 'Meena', '192.168.1.4', 'Shoes', 2500.00, TRUE, FALSE, 'Completed'),
# (5, 'Desktop', 'Karthik', '192.168.1.5', 'Watch', 5000.00, TRUE, TRUE, 'Completed'),
# (6, 'Mobile', 'Sowmya', '192.168.1.6', 'Tablet', 15000.00, TRUE, TRUE, 'Completed'),
# (7, 'Tablet', 'Ramesh', '192.168.1.7', 'Smartphone', 25000.00, FALSE, TRUE, 'Failed'),
# (8, 'Desktop', 'Divya', '192.168.1.8', 'Laptop', 60000.00, TRUE, FALSE, 'Completed'),
# (9, 'Mobile', 'Arun', '192.168.1.9', 'Smartwatch', 12000.00, TRUE, TRUE, 'Completed'),
# (10, 'Tablet', 'Deepa', '192.168.1.10', 'Laptop', 55000.00, FALSE, FALSE, 'Pending');

# %%
# %%sql
# select * from CustomerTransactions;

# %%
# %%sql
# select sum(amount) as total_transactions from CustomerTransactions where transaction_status = "Completed"

# %%
# %%sql
# select distinct(transaction_status) from CustomerTransactions;

# %%
# %%sql
# select count(*) from CustomerTransactions where transaction_status not in("Pending","Failed");

# %%
# %%sql
# select min(amount) as minimumamount from CustomerTransactions;

# %%
# %%sql
# select max(amount) as maximumamount from CustomerTransactions;

# %%
# %%sql
# select avg(amount) as avg_amount from CustomerTransactions;

# %%
# %%sql
# select login_device,sum(amount) as total_revenue from CustomerTransactions group by login_device order by total_revenue desc limit 1;

# %%
# %%sql
# select customer_name,login_device,sum(amount) as total_revenue from CustomerTransactions group by customer_name,login_device order by total_revenue desc;

# %%
# %%sql
# select login_device,sum(amount) as total_revenue from CustomerTransactions group by login_device having total_revenue > 80000;

# %%
# %%sql
# select case
#        when 8 > 10 then 'first condition satisfied'
#        when 10 > 8 then 'second condition satisfted'
#        else 'any condition not satisfied'
# end as test;

# %%
# %%sql
# desc CustomerTransactions;

# %%
# %%sql
# select customer_name,amount,case
#                             when amount > 4000 then 'High spender'
#                             when amount between 2000 and 4000 then 'Medium spender'
#                             else 'Low spender'
#                             end as spending from CustomerTransactions;

# %%
# %%sql
# INSERT into CustomerTransactions values (11, 'Tablet', 'Arjun', '192.168.1.3', 'Headphones', 3500.00, FALSE, TRUE, 'Completed');

# %%
# %%sql
# select customer_name,sum(amount) as sumamount,case
#                             when sum(amount) > 4000 then 'High spender'
#                             when sum(amount) between 2000 and 4000 then 'Medium spender'
#                             else 'Low spender'
#                             end as spending from CustomerTransactions group by customer_name ;

# %%
# %%sql
# CREATE TABLE CustomerData (
#     id INT PRIMARY KEY,
#     customer_name VARCHAR(100),
#     email VARCHAR(100),
#     phone_number VARCHAR(15),
#     address VARCHAR(200),
#     amount DECIMAL(10, 2)
# );

# %%
# %%sql
# INSERT INTO CustomerData VALUES
# (1, 'Ravi', 'ravi@example.com', '9876', 'Chennai', 5000.00),
# (2, 'Priya', NULL, '9876', 'Bangalore', NULL),
# (3, 'Arjun', 'arjun@example.com', NULL, 'Hyderabad', 1500.00),
# (4, 'Meena', NULL, NULL, 'Mumbai', 2500.00),
# (5, 'Karthik', 'karthik@example.com', '9876', NULL, 3000.00);

# %%
# %%sql
# select customer_name,case
#                      when phone_number is null and email is null then '9999'
#                      when phone_number is null then email
#                      else phone_number
#                      end as contact from CustomerData;

# %%
# %%sql
# select customer_name,COALESCE(email,"dummy") from CustomerData;

# %%
# %%sql
# create table customerDetails(id int primary key,customer_name varchar(50),email varchar(100),city varchar(100),phone_number varchar(100));

# %%
# %%sql
# insert into customerDetails values(1,"Ravi Kumar","ravi.kumar@example.com","Chennai","43210"),(2,"Priya Sharma","priya.sharma@example.com","Bangalore","43211"),(3,"Arjun Mehta","arjun.mehta@example.com","Hyderabad","43212"),(4,"Meena Gupta","meena.gupta@example.com","Mumbai",NULL),(5,"Karthik Raj","karthik.raj@example.com","Chennai","43213");

# %%
# %%sql
# select * from customerDetails;

# %%
# %%sql
# select length(customer_name) as name_length,
#         upper(city) as city_upper,
#         lower(customer_name) as cust_lower,
#         concat(customer_name,'::',city) as name_c,
#         SUBSTRING(customer_name,1,6) as name_prefix,
#         TRIM('     Chennai    ') as trimmed_city,
#         LPAD(customer_name,15,'*') as left_padded_name,
#         REPLACE(customer_name,' ',"_") as updated_name,
#         INSTR(customer_name,"a") as position_of_a,
#         LEFT(customer_name,5) as first_five_chars,
#         RIGHT(customer_name,5) as last_five_chars,
#         REVERSE(customer_name) as reversed_name,
#         FORMAT(9876543210,2) as formatted
#
#
# from customerDetails;

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql
