# %%
# %load_ext sql

# %%
# %sql mysql+mysqlconnector://root:Test%401234@localhost/dataengineering

# %%
# %%sql
# CREATE TABLE sales (
#     TransactionID INT,
#     Store VARCHAR(50),
#     SalesAmount DECIMAL(10, 2)
# );
#
# INSERT INTO sales (TransactionID, Store, SalesAmount)
# VALUES
#     (1, 'A', 100.00),
#     (2, 'A', 200.00),
#     (3, 'A', 150.00),
#     (4, 'B', 250.00),
#     (5, 'B', 300.00);

# %%
# %%sql
# select * from sales;

# %%
# %%sql
# select *,sum(SalesAmount) over() as totalsales from sales;

# %%
# %%sql
# select *,sum(SalesAmount) over(partition by store) as totalsales from sales;

# %%
# %%sql
# select *,sum(SalesAmount) over(partition by store order by TransactionID DESC) as totalsales from sales;

# %% [markdown]
# 🔹 1. Aggregate Functions (as Window Functions)
#
# SUM()
#
# AVG()
#
# MIN()
#
# MAX()
#
# COUNT()
#
# 🔹 2. Ranking Functions
#
# ROW_NUMBER()
#
# RANK()
#
# DENSE_RANK()
#
# NTILE(n)
#
# 🔹 3. Value Functions
#
# LAG(expr, offset, default) → previous row value
#
# LEAD(expr, offset, default) → next row value
#
# FIRST_VALUE(expr) → first value in the window
#
# LAST_VALUE(expr) → last value in the window

# %%
# %%sql
# select * from sales;

# %%
# %%sql
# select TransactionID,Store,SalesAmount,ROW_NUMBER() over(partition by store order by SalesAmount desc) from sales;

# %%
# %%sql
# drop table if exists Employees;
# CREATE TABLE Employees (
#     EmployeeID INT,
#     Name VARCHAR(100),
#     Department VARCHAR(50),
#     HireDate DATE
# );
#
#
# INSERT INTO Employees (EmployeeID, Name, Department, HireDate)
# VALUES
#     (1, 'Alice', 'HR', '2020-05-01'),
#     (1, 'Alice', 'HR', '2022-06-15'),
#     (2, 'Bob', 'IT', '2021-07-10'),
#     (3, 'Charlie', 'Finance', '2020-09-30'),
#     (3, 'Charlie', 'Finance', '2022-05-22');

# %%
# %%sql
# select * from Employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 5 rows affected.
# [(1, 'Alice', 'HR', datetime.date(2020, 5, 1)),
#  (1, 'Alice', 'HR', datetime.date(2022, 6, 15)),
#  (2, 'Bob', 'IT', datetime.date(2021, 7, 10)),
#  (3, 'Charlie', 'Finance', datetime.date(2020, 9, 30)),
#  (3, 'Charlie', 'Finance', datetime.date(2022, 5, 22))]

# %%
# %%sql
# WITH EmployeeBank as(select EmployeeID,Name,Department,HireDate,ROW_NUMBER() OVER(PARTITION BY EmployeeID ORDER BY HireDate) as rownum from Employees)
#
# select * from EmployeeBank where rownum > 1;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 2 rows affected.
# [(1, 'Alice', 'HR', datetime.date(2022, 6, 15), 2),
#  (3, 'Charlie', 'Finance', datetime.date(2022, 5, 22), 2)]

# %%
# %%sql
# select EmployeeID from EmployeeBank;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# (mysql.connector.errors.ProgrammingError) 1146 (42S02): Table 'dataengineering.EmployeeBank' doesn't exist
# [SQL: select EmployeeID from EmployeeBank;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# WITH EmployeeBank AS (
#     SELECT
#         EmployeeID,
#         Name,
#         Department,
#         HireDate,
#         ROW_NUMBER() OVER (PARTITION BY EmployeeID ORDER BY HireDate) AS rownum
#     FROM Employees
# )
# SELECT *
# FROM EmployeeBank where rownum = 1;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 3 rows affected.
# [(1, 'Alice', 'HR', datetime.date(2020, 5, 1), 1),
#  (2, 'Bob', 'IT', datetime.date(2021, 7, 10), 1),
#  (3, 'Charlie', 'Finance', datetime.date(2020, 9, 30), 1)]

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql
