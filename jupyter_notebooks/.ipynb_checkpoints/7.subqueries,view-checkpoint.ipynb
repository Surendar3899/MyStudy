# %%
# %load_ext sql

# %%
# %sql mysql+mysqlconnector://root:Test%401234@localhost/dataengineering

# %%
# %%sql
# show tables;

# %%
# %%sql
# create table customers(customer_id int primary key,customer_name varchar(50),city varchar(50))

# %%
# %%sql
# create table orders(order_id int primary key,customer_id int,order_amount decimal(10,2),order_date date,foreign key(customer_id) references customers(customer_id))

# %%
# %%sql
# INSERT INTO customers (customer_id, customer_name, city) VALUES
# (1, 'Arun Kumar', 'Chennai'),
# (2, 'Meena R', 'Coimbatore'),
# (3, 'Suresh B', 'Madurai'),
# (4, 'Divya P', 'Bangalore'),
# (5, 'Karthik N', 'Hyderabad');

# %%
# %%sql
# INSERT INTO orders (order_id, customer_id, order_amount, order_date) VALUES
# (101, 1, 2500.50, '2025-08-01'),
# (102, 2, 1800.00, '2025-08-05'),
# (103, 3, 3200.75, '2025-08-10'),
# (104, 1, 1500.00, '2025-08-15'),
# (105, 4, 2200.25, '2025-08-20');

# %%
# %%sql
# select * from orders;

# %%
# %%sql
# select customer_name,(select max(order_amount) from orders) as max_amount_orders from customers;

# %%
# %%sql
# select customer_name from customers where customer_id = (select customer_id from orders where order_amount = (select max(order_amount) from orders))

# %%
# %%sql
# select customer_name from customers where customer_id = (select customer_id from orders where order_amount = (select max(order_amount) from orders))

# %%
# %%sql
# select distinct(customer_id) from orders where order_amount > 1400;

# %%
# %%sql
# SELECT *
# FROM orders
# WHERE order_date < NOW() - INTERVAL 20 DAY;

# %%
# %%sql
# select * from customers;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 5 rows affected.
# [(1, 'Arun Kumar', 'Chennai'),
#  (2, 'Meena R', 'Coimbatore'),
#  (3, 'Suresh B', 'Madurai'),
#  (4, 'Divya P', 'Bangalore'),
#  (5, 'Karthik N', 'Hyderabad')]

# %%
# %%sql
# select * from orders;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 5 rows affected.
# [(101, 1, Decimal('2500.50'), datetime.date(2025, 8, 1)),
#  (102, 2, Decimal('1800.00'), datetime.date(2025, 8, 5)),
#  (103, 3, Decimal('3200.75'), datetime.date(2025, 8, 10)),
#  (104, 1, Decimal('1500.00'), datetime.date(2025, 8, 15)),
#  (105, 4, Decimal('2200.25'), datetime.date(2025, 8, 20))]

# %%
# %%sql
# select customer_name from customers where customer_id in (select (customer_id) from orders group by customer_id having sum(order_amount) > 3000)
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 2 rows affected.
# [('Arun Kumar',), ('Suresh B',)]

# %%
# %%sql
# select (customer_id),sum(order_amount) as sumamount from orders group by customer_id having sumamount > 3000
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 2 rows affected.
# [(1, Decimal('4000.50')), (3, Decimal('3200.75'))]

# %%
# %%sql
# select customer_name,city,(select sum(order_amount) from orders o where o.customer_id = c.customer_id) as totalsum  FROM customers c;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 5 rows affected.
# [('Arun Kumar', 'Chennai', Decimal('4000.50')),
#  ('Meena R', 'Coimbatore', Decimal('1800.00')),
#  ('Suresh B', 'Madurai', Decimal('3200.75')),
#  ('Divya P', 'Bangalore', Decimal('2200.25')),
#  ('Karthik N', 'Hyderabad', None)]

# %%
# %%sql
# CREATE TABLE Employees (
#     EmployeeID INT PRIMARY KEY,
#     FirstName  VARCHAR(50),
#     LastName   VARCHAR(50),
#     Salary     DECIMAL(10,2),
#     Department VARCHAR(50)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# (mysql.connector.errors.ProgrammingError) 1050 (42S01): Table 'Employees' already exists
# [SQL: CREATE TABLE Employees (
#     EmployeeID INT PRIMARY KEY,
#     FirstName  VARCHAR(50),
#     LastName   VARCHAR(50),
#     Salary     DECIMAL(10,2),
#     Department VARCHAR(50)
# );]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# CREATE TABLE Employees1 (
#     EmployeeID INT PRIMARY KEY,
#     FirstName  VARCHAR(50),
#     LastName   VARCHAR(50),
#     Salary     DECIMAL(10,2),
#     Department VARCHAR(50)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 0 rows affected.
# []

# %%
# %%sql
# INSERT INTO Employees1 (EmployeeID, FirstName, LastName, Salary, Department)
# VALUES
#     (1, 'Alice', 'Johnson', 55000.00, 'Sales'),
#     (2, 'Bob',   'Smith',   60000.00, 'IT'),
#     (3, 'Carol', 'Davis',   52000.00, 'Sales'),
#     (4, 'Dave',  'Wilson',  58000.00, 'HR');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 4 rows affected.
# []

# %%
# %%sql
# CREATE VIEW SalesEmployees AS
# SELECT EmployeeID, FirstName, LastName, Salary
# FROM Employees1
# WHERE Department = 'Sales';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 0 rows affected.
# []

# %%
# %%sql
# select * from SalesEmployees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 2 rows affected.
# [(1, 'Alice', 'Johnson', Decimal('55000.00')),
#  (3, 'Carol', 'Davis', Decimal('52000.00'))]

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql
