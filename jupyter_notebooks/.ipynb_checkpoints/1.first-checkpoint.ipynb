# %%
# %load_ext sql

# %%
# %sql mysql+mysqlconnector://root:Test%401234@localhost/dataengineering

# %%
# %%sql
# show databases;
# use dataengineering;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 15 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# create table test(sno int,name varchar(100));
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 0 rows affected.
# []

# %%
# %%sql
# insert into test(sno,name) values (1,"surendar"),(9,"susi");
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 2 rows affected.
# []

# %%
# %%sql
# show tables;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 1 rows affected.
# [('test',)]

# %%
# %%sql
# select * from test;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 2 rows affected.
# [(1, 'surendar'), (9, 'susi')]

# %%
# %%sql
# update test set name = "newsurendar",sno=2 where sno=1;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 1 rows affected.
# []

# %%
# %%sql
# select * from test;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 2 rows affected.
# [(2, 'newsurendar'), (9, 'susi')]

# %%
# %%sql
# delete from test where sno = 2;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 1 rows affected.
# []

# %%
# %%sql
# select * from test;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 1 rows affected.
# [(9, 'susi')]

# %%
# %%sql
# truncate table test;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 0 rows affected.
# []

# %%
# %%sql
# select * from test;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 0 rows affected.
# []

# %%
# %%sql
# drop table test;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 0 rows affected.
# []

# %%
# %%sql
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# (mysql.connector.errors.ProgrammingError) 1146 (42S02): Table 'dataengineering.test' doesn't exist
# [SQL: select * from test;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql
