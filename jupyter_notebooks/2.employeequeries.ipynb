# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql mysql+mysqlconnector://root:Test%401234@localhost/randomgenerateCREATE TABLE Employee (
    emp_id INT,
    emp_name VARCHAR(50),
    salary INT
);

INSERT INTO Employee VALUES
(1, 'Alice', 10000),
(2, 'Bob', 9000),
(3, 'Charlie', 9000),
(4, 'David', 8000),
(5, 'Emma', 7000),
(6, 'Frank', 7000);

# %%
# %%sql
# show databases;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/randomgenerate
# 15 rows affected.
# [('cacheapp',),
#  ('conquer',),
#  ('course_reg_sym',),
#  ('dataengineering',),
#  ('gavs',),
#  ('information_schema',),
#  ('jvlcart',),
#  ('jwtsecuritydemo',),
#  ('mysql',),
#  ('performance_schema',),
#  ('practice',),
#  ('randomgenerate',),
#  ('revotranemployeesystem',),
#  ('securitydemo',),
#  ('sys',)]

# %%
# %%sql
# use randomgenerate;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/randomgenerate
# 0 rows affected.
# []

# %%
# %%sql
# show tables;

# %%
# %%sql
# select * from employees where manager_id IS NULL;

# %%
# %%sql
# select e.*,m.name as managername from employees e left join employees m on e.manager_id = m.id;

# %%
# %%sql
# select e.*,m.name as managername,m.salary as managersalary from employees e right join employees m on e.manager_id=m.id where e.salary > m.salary;

# %%
# %%sql
# desc employees;

# %%
# %%sql
# SELECT m.id AS manager_id,
#        m.name AS manager_name,
#        AVG(e.salary) AS avg_team_salary
# FROM employees e
# JOIN employees m
#     ON e.manager_id = m.id
# WHERE e.designation != 'Manager'  -- exclude managers from team members
# GROUP BY m.id, m.name
# ORDER BY avg_team_salary DESC
# LIMIT 1;

# %%
# %%sql
# SELECT m.id AS manager_id,
#        m.name AS manager_name,
#        MAX(e.salary) AS avg_team_salary
# FROM employees e
# JOIN employees m
#     ON e.manager_id = m.id
# WHERE e.designation != 'Manager'  -- exclude managers from team members
# GROUP BY m.id, m.name LIMIT 1;

# %%
# %%sql
# select m.name,count(e.id) from employees m join employees e on m.id = e.manager_id where e.designation != 'Manager' GROUP BY m.id;

# %%
# %%sql
# SELECT m.name AS manager_name,
#        COUNT(e.id) AS employee_count
# FROM employees m
# JOIN employees e
#     ON m.id = e.manager_id
# WHERE e.designation != 'Manager'
# GROUP BY m.id;

# %%
# %%sql
# SELECT COUNT(name) AS name
# FROM employees
# GROUP BY salary;

# %%
# %%sql
# select * from employees where salary = (select max(salary) from employees)
# Out:
#  * mysql+mysqlconnector://root:***@localhost/randomgenerate
# 1 rows affected.
# [(17, 'Priya Sharma', 'priya.sharma@company.com', Decimal('113818.00'), datetime.date(2021, 10, 10), 'Manager', None)]

# %%
# %%sql
# create temporary table temp_high_salary_employee as select * from employees where salary = (select max(salary) from employees);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/randomgenerate
# 1 rows affected.
# []

# %%
# %%sql
# select * from high_salary_employee;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/randomgenerate
# 1 rows affected.
# [(18, 'Mike Johnson', 'mike.johnson@company.com', Decimal('119877.00'), datetime.date(2022, 6, 30), 'Manager', None)]

# %%
# %%sql
# select * from temp_high_salary_employee;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/randomgenerate
# 1 rows affected.
# [(17, 'Priya Sharma', 'priya.sharma@company.com', Decimal('113818.00'), datetime.date(2021, 10, 10), 'Manager', None)]

# %%
# %%sql
# update employees set salary = 0 where salary = (select max_salary from (select max(salary) as max_salary from employees) as t);

# %%
# %%sql
# select * from employees where salary = (select max(salary) from employees)

# %%
# %%sql
# update employees set salary = 0 where salary = (select max_salary from (select max(salary) as max_salary from employees) as t);

# %%
# %%sql
# select * from employees where salary = (select max(salary) from employees)

# %%
# %%sql
# #Find employees who joined before 6 months
# SELECT *
# FROM employees
# WHERE DATEDIFF(CURDATE(), joining_date) > 180
# order by joining_date desc;

# %%
# %%sql
# #Find employees who joined in the last 6 months
# SELECT *
# FROM employees
# WHERE joining_date >= DATE_SUB(CURDATE(), INTERVAL 6 YEAR);

# %%
# %%sql
# desc employees;

# %%
# %%sql
# select * from employees;

# %%
# %%sql
# SELECT *
# FROM employees
# WHERE name LIKE 'J%n';

# %%
# %%sql
# select * from employees where joining_date >= NOW()-INTERVAL  12 MONTH ORDER BY joining_date

# %%
# %%sql
# select * from employees where manager_id is null;

# %%
# %%sql
# select sum(salary),avg(salary),count(*),designation from employees group by designation;

# %%
# %%sql
# select count(*) as counting,designation from employees group by designation having counting > 6;

# %%
# %%sql
# select e.name,e.salary,e.designation from employees e where e.salary = (select max(salary) from employees where designation = e.designation)

# %%
# %%sql
# select e.name as empname,m.name as managername from employees e join employees m on e.manager_id = m.id;

# %%
# %%sql
# select * from employees where salary > (select avg(salary) from employees)

# %%
# %%sql
# select * from employees order by salary desc
# Out:
#  * mysql+mysqlconnector://root:***@localhost/randomgenerate
# (mysql.connector.errors.OperationalError) 2055: Lost connection to MySQL server at 'localhost:3306', system error: 32 Broken pipe
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %%sql
# select max(salary) from employees where salary < (select max(salary) from employees)

# %%
# %%sql
# SELECT *
# FROM employees
# ORDER BY salary DESC
# LIMIT 1 OFFSET 1;

# %%
# %%sql
# update employees set email = "john.williams@gmail.com" where email = "john.williams@company.com"

# %%
# %%sql
#
# CREATE TABLE Employee (
#     emp_id INT,
#     emp_name VARCHAR(50),
#     salary INT
# );
#
# INSERT INTO Employee VALUES
# (1, 'Alice', 10000),
# (2, 'Bob', 9000),
# (3, 'Charlie', 9000),
# (4, 'David', 8000),
# (5, 'Emma', 7000),
# (6, 'Frank', 7000);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/randomgenerate
# 0 rows affected.
# 6 rows affected.
# []

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql
