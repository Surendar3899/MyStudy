# %%
# %load_ext sql

# %%
# %sql mysql+mysqlconnector://root:Test%401234@localhost/dataengineering

# %%
# %%sql
# show databases;

# %%
# %%sql
# drop table if exists employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 0 rows affected.
# []

# %%
# %%sql
# create table employees(EmployeeID INT PRIMARY KEY,firstName VARCHAR(50),lastName VARCHAR(50))
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 0 rows affected.
# []

# %%
# %%sql
# desc employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 3 rows affected.
# [('EmployeeID', 'int', 'NO', 'PRI', None, ''),
#  ('firstName', 'varchar(50)', 'YES', '', None, ''),
#  ('lastName', 'varchar(50)', 'YES', '', None, '')]

# %%
# %%sql
# alter table employees add email varchar(100);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 0 rows affected.
# []

# %%
# %%sql
# desc employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 3 rows affected.
# [('EmployeeID', 'int', 'NO', 'PRI', None, ''),
#  ('firstName', 'varchar(50)', 'YES', '', None, ''),
#  ('email', 'varchar(100)', 'YES', '', None, '')]

# %%
# %%sql
# alter table employees drop column lastName;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 0 rows affected.
# []

# %%
# %%sql
# alter table employees rename to Employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 0 rows affected.
# []

# %%
# %%sql
# create table rides(ride_id int primary key,driver_id int,rider_id int,pickup_location varchar(100),dropoff_location varchar(100),ride_date DATETIME,fare decimal(10,2))
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 0 rows affected.
# []

# %%
# %%sql
# ALTER TABLE rides MODIFY ride_id INT;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 0 rows affected.
# []

# %%
# %%sql
# ALTER TABLE rides DROP PRIMARY KEY;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 0 rows affected.
# []

# %%
# %%sql
# desc rides;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 7 rows affected.
# [('ride_id', 'int', 'NO', '', None, ''),
#  ('driver_id', 'int', 'YES', '', None, ''),
#  ('rider_id', 'int', 'YES', '', None, ''),
#  ('pickup_location', 'varchar(100)', 'YES', '', None, ''),
#  ('dropoff_location', 'varchar(100)', 'YES', '', None, ''),
#  ('ride_date', 'datetime', 'YES', '', None, ''),
#  ('fare', 'decimal(10,2)', 'YES', '', None, '')]

# %%
# %%sql
# INSERT INTO rides (ride_id, driver_id, rider_id, pickup_location, dropoff_location, ride_date, fare)
# VALUES
# (1, 101, 201, 'Chennai Central', 'Chennai Airport', '2025-08-10 09:15:00', 350.00),
#
# (2, 102, 202, 'Coimbatore Town Hall', 'Coimbatore Airport', '2025-08-11 14:30:00', 420.50),
#
# (3, 103, 203, 'Madurai Meenakshi Temple', 'Madurai Junction', '2025-08-12 08:45:00', 250.00),
#
# (4, 104, 204, 'Bangalore Majestic', 'Bangalore Whitefield', '2025-08-13 19:20:00', 550.75),
#
# (5, 105, 205, 'Chennai T Nagar', 'Coimbatore Gandhipuram', '2025-08-14 06:50:00', 1500.00);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 5 rows affected.
# []

# %%
# %%sql
# select * from rides;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 5 rows affected.
# [(1, 101, 201, 'Chennai Central', 'Chennai Airport', datetime.datetime(2025, 8, 10, 9, 15), Decimal('350.00')),
#  (2, 102, 202, 'Coimbatore Town Hall', 'Coimbatore Airport', datetime.datetime(2025, 8, 11, 14, 30), Decimal('420.50')),
#  (3, 103, 203, 'Madurai Meenakshi Temple', 'Madurai Junction', datetime.datetime(2025, 8, 12, 8, 45), Decimal('250.00')),
#  (4, 104, 204, 'Bangalore Majestic', 'Bangalore Whitefield', datetime.datetime(2025, 8, 13, 19, 20), Decimal('550.75')),
#  (5, 105, 205, 'Chennai T Nagar', 'Coimbatore Gandhipuram', datetime.datetime(2025, 8, 14, 6, 50), Decimal('1500.00'))]

# %%
# %%sql
# select * from rides where ride_date > DATE_SUB(CURDATE(),INTERVAL 2 DAY)
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 1 rows affected.
# [(5, 105, 205, 'Chennai T Nagar', 'Coimbatore Gandhipuram', datetime.datetime(2025, 8, 14, 6, 50), Decimal('1500.00'))]

# %%
# %%sql
# select * from rides where fare > '500.75' and dropoff_location = 'Coimbatore Gandhipuram' order by fare desc;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 1 rows affected.
# [(5, 105, 205, 'Chennai T Nagar', 'Coimbatore Gandhipuram', datetime.datetime(2025, 8, 14, 6, 50), Decimal('1500.00'))]

# %%
#constraint

# %%
# %%sql
# drop table if exists rides;
# create table rides(ride_id int primary key,driver_id int not null,rider_id int not null,pickup_location varchar(100) not null,dropoff_location varchar(100) not null,ride_date DATETIME not null,fare decimal(10,2) not null)
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# desc rides;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 7 rows affected.
# [('ride_id', 'int', 'NO', 'PRI', None, ''),
#  ('driver_id', 'int', 'NO', '', None, ''),
#  ('rider_id', 'int', 'NO', '', None, ''),
#  ('pickup_location', 'varchar(100)', 'NO', '', None, ''),
#  ('dropoff_location', 'varchar(100)', 'NO', '', None, ''),
#  ('ride_date', 'datetime', 'NO', '', None, ''),
#  ('fare', 'decimal(10,2)', 'NO', '', None, '')]

# %%
# %%sql
# drop table if exists rides;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 0 rows affected.
# []

# %%
# %%sql
# create table rides(ride_id int,driver_id int not null,rider_id int not null,pickup_location varchar(100) not null,dropoff_location varchar(100) not null,ride_date DATETIME not null,fare decimal(10,2) not null,primary key(ride_id,rider_id))
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 0 rows affected.
# []

# %%
# %%sql
# desc rides;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 7 rows affected.
# [('ride_id', 'int', 'NO', 'PRI', None, ''),
#  ('driver_id', 'int', 'NO', '', None, ''),
#  ('rider_id', 'int', 'NO', 'PRI', None, ''),
#  ('pickup_location', 'varchar(100)', 'NO', '', None, ''),
#  ('dropoff_location', 'varchar(100)', 'NO', '', None, ''),
#  ('ride_date', 'datetime', 'NO', '', None, ''),
#  ('fare', 'decimal(10,2)', 'NO', '', None, '')]

# %%
# %%sql
# create table users(user_id int primary key,email varchar(100) unique);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 0 rows affected.
# []

# %%
# %%sql
# desc users;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 2 rows affected.
# [('user_id', 'int', 'NO', 'PRI', None, ''),
#  ('email', 'varchar(100)', 'YES', 'UNI', None, '')]

# %%
# %%sql
# drop tables users;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 0 rows affected.
# []

# %%
# %%sql
# drop table if exists rides;
# create table rides(ride_id int,driver_id int not null,rider_id int not null,pickup_location varchar(100) not null,dropoff_location varchar(100) not null,ride_date DATETIME not null,fare decimal(10,2) not null check(fare>0),primary key(ride_id,rider_id))
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# INSERT INTO rides (ride_id, driver_id, rider_id, pickup_location, dropoff_location, ride_date, fare)
# VALUES
# (1, 101, 201, 'Chennai Central', 'Chennai Airport', '2025-08-10 09:15:00', -350.00);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# (mysql.connector.errors.DatabaseError) 3819 (HY000): Check constraint 'rides_chk_1' is violated.
# [SQL: INSERT INTO rides (ride_id, driver_id, rider_id, pickup_location, dropoff_location, ride_date, fare)
# VALUES
# (1, 101, 201, 'Chennai Central', 'Chennai Airport', '2025-08-10 09:15:00', -350.00);]
# (Background on this error at: https://sqlalche.me/e/20/4xp6)

# %%
# %%sql
# drop table if exists rides;
# drop table if exists drivers;
#
# create table drivers(driver_id int primary key,driver_name varchar(100) not null,license_number varchar(50) unique);
# create table rides(ride_id int,driver_id int not null,rider_id int not null,pickup_location varchar(100) not null,dropoff_location varchar(100) not null,ride_date DATETIME not null,fare decimal(10,2) not null check(fare>0),foreign key(driver_id) references drivers(driver_id))
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# desc drivers;
# desc rides;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 3 rows affected.
# 7 rows affected.
# [('ride_id', 'int', 'YES', '', None, ''),
#  ('driver_id', 'int', 'NO', 'MUL', None, ''),
#  ('rider_id', 'int', 'NO', '', None, ''),
#  ('pickup_location', 'varchar(100)', 'NO', '', None, ''),
#  ('dropoff_location', 'varchar(100)', 'NO', '', None, ''),
#  ('ride_date', 'datetime', 'NO', '', None, ''),
#  ('fare', 'decimal(10,2)', 'NO', '', None, '')]

# %%
# %%sql
# INSERT INTO drivers (driver_id, driver_name, license_number)
# VALUES (101, 'John Doe', 'XYZ12345'), (102, 'Jane Smith', 'ABC67890');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 2 rows affected.
# []

# %%
# %%sql
# INSERT INTO rides (ride_id, driver_id, pickup_location, dropoff_location, ride_date, fare,rider_id)
# VALUES
# (301, 101, 'Chennai', 'Coimbatore', '2024-12-01 08:00:00', 500.00,1),
# (302, 101, 'Chennai', 'Madurai', '2024-12-01 09:30:00', 600.00,2),
# (303, 102, 'Bangalore', 'Hyderabad', '2024-12-02 10:00:00', 700.00,3);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 3 rows affected.
# []

# %%
# %%sql
# select * from rides;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 3 rows affected.
# [(301, 101, 1, 'Chennai', 'Coimbatore', datetime.datetime(2024, 12, 1, 8, 0), Decimal('500.00')),
#  (302, 101, 2, 'Chennai', 'Madurai', datetime.datetime(2024, 12, 1, 9, 30), Decimal('600.00')),
#  (303, 102, 3, 'Bangalore', 'Hyderabad', datetime.datetime(2024, 12, 2, 10, 0), Decimal('700.00'))]

# %%
# %%sql
# delete from drivers where driver_id = 101;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 1 rows affected.
# []

# %%
# %%sql
# delete from rides where driver_id = 101;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 2 rows affected.
# []

# %%
# %%sql
# drop table if exists rides;
# drop table if exists drivers;
#
# create table drivers(driver_id int primary key,driver_name varchar(100) not null,license_number varchar(50) unique);
# create table rides(ride_id int,driver_id int not null,rider_id int not null,pickup_location varchar(100) not null,dropoff_location varchar(100) not null,ride_date DATETIME not null,fare decimal(10,2) not null check(fare>0),foreign key(driver_id) references drivers(driver_id) on delete cascade)
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# desc rides;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 7 rows affected.
# [('ride_id', 'int', 'YES', '', None, ''),
#  ('driver_id', 'int', 'NO', 'MUL', None, ''),
#  ('rider_id', 'int', 'NO', '', None, ''),
#  ('pickup_location', 'varchar(100)', 'NO', '', None, ''),
#  ('dropoff_location', 'varchar(100)', 'NO', '', None, ''),
#  ('ride_date', 'datetime', 'NO', '', None, ''),
#  ('fare', 'decimal(10,2)', 'NO', '', None, '')]

# %%
# %%sql
# select * from rides;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 1 rows affected.
# [(303, 102, 3, 'Bangalore', 'Hyderabad', datetime.datetime(2024, 12, 2, 10, 0), Decimal('700.00'))]

# %%
# %%sql
# delete from drivers where driver_id = 101;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 1 rows affected.
# []

# %%
# %%sql
# #soft delete column add
# alter table rides add column is_delete boolean default false;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 0 rows affected.
# []

# %%
# %%sql
# desc rides;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 8 rows affected.
# [('ride_id', 'int', 'YES', '', None, ''),
#  ('driver_id', 'int', 'NO', 'MUL', None, ''),
#  ('rider_id', 'int', 'NO', '', None, ''),
#  ('pickup_location', 'varchar(100)', 'NO', '', None, ''),
#  ('dropoff_location', 'varchar(100)', 'NO', '', None, ''),
#  ('ride_date', 'datetime', 'NO', '', None, ''),
#  ('fare', 'decimal(10,2)', 'NO', '', None, ''),
#  ('is_delete', 'tinyint(1)', 'YES', '', '0', '')]

# %%
# %%sql
# select * from rides;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 1 rows affected.
# [(303, 102, 3, 'Bangalore', 'Hyderabad', datetime.datetime(2024, 12, 2, 10, 0), Decimal('700.00'), 0, None, '')]

# %%
# %%sql
# alter table rides add column is_check varchar(100);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 0 rows affected.
# []

# %%
# %%sql
# alter table rides drop column is_check2;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/dataengineering
# 0 rows affected.
# []

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql

# %%
# %%sql
